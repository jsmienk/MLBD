# %% [markdown]
# # Movie Recommendation
#
# later

# %%
# Core
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# SKLearn
import sklearn
from sklearn.feature_extraction.text import CountVectorizer

# NLTK
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from nltk.stem.snowball import SnowballStemmer

# Display
from IPython.core.display import HTML
from movie_display import movie_display
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/jeroen/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# Import movies into a data frame and analyze the availables attributes.
#
# ## IMDb JSON
#
# 9125 Movies with 18 attributes from IMDb.
#
# Attributes:
#
# - Actors
# - ...
# - Plot
# - Title
# - Writer
# - ...
# - imdbVotes

# %%
# Load movies into a dataframe
df = pd.read_json('./dataset/imdbdata.json', orient='columns')
df.head(2)
# Out:
#                                               Actors  \
# 0      Tom Hanks, Tim Allen, Don Rickles, Jim Varney
# 1  Robin Williams, Jonathan Hyde, Kirsten Dunst, ...
#
#                                               Awards Country       Director  \
# 0  Nominated for 3 Oscars. Another 23 wins & 18 n...     USA  John Lasseter
# 1                            4 wins & 9 nominations.     USA   Joe Johnston
#
#                           Genre         Language  \
# 0  Animation, Adventure, Comedy          English
# 1     Action, Adventure, Family  English, French
#
#                                                 Plot  \
# 0  A cowboy doll is profoundly threatened and jea...
# 1  When two kids find and play a magical board ga...
#
#                                               Poster  \
# 0  https://images-na.ssl-images-amazon.com/images...
# 1  https://images-na.ssl-images-amazon.com/images...
#
#                          Production Rated     Released  Runtime      Title  \
# 0                       Buena Vista     G  22 Nov 1995   81 min  Toy Story
# 1  Sony Pictures Home Entertainment    PG  15 Dec 1995  104 min    Jumanji
#
#                                               Writer  Year  imdbId imdbRating  \
# 0  John Lasseter (original story by), Pete Docter...  1995  114709        8.3
# 1  Jonathan Hensleigh (screenplay), Greg Taylor (...  1995  113497        6.9
#
#   imdbVotes
# 0   666,855
# 1   223,000

# %% [markdown]
# ### Feature Extraction
#
# Pipeline: https://stackoverflow.com/questions/36182502/add-stemming-support-to-countvectorizer-sklearn
#
# Excluding stopwords and stemming words according to the NLTK English language dictionaries.
#
# #### Stopwords
#
# #### Stemming
#
# Useful but also transforms correct words into incorrect ones. Like `james` to `jame` and `territory` to `terri`.

# %%
features = df.copy()

# Get the stopwords for the English language
useless_words = stopwords.words('english')
# Create a stemmer for the English language
stemmer = SnowballStemmer("english", ignore)

print(useless_words[:10])
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're"]

# %%
plots = []
for sentence in features.Plot:
    words = sentence.lower().split()
    words = [stemmer.stem(w) for w in words if w not in useless_words]
    plots.append(' '.join(words))

features['PlotStripped'] = plots

vectorizer = CountVectorizer()
bag_of_words = vectorizer.fit(plots).transform(plots)
print(bag_of_words)
# Out:
#   (0, 2150)	1
#   (0, 3699)	1
#   (0, 4702)	1
#   (0, 5894)	1
#   (0, 8268)	1
#   (0, 10725)	1
#   (0, 12250)	1
#   (0, 13292)	1
#   (0, 14508)	1
#   (0, 15067)	1
#   (0, 15544)	1
#   (0, 15689)	1
#   (0, 15753)	1
#   (1, 1993)	1
#   (1, 3989)	1
#   (1, 4114)	1
#   (1, 5920)	1
#   (1, 5926)	1
#   (1, 6389)	2
#   (1, 7485)	1
#   (1, 8596)	1
#   (1, 9471)	1
#   (1, 9557)	1
#   (1, 11864)	1
#   (1, 12845)	1
#   :	:
#   (9123, 11433)	1
#   (9123, 12331)	1
#   (9123, 13105)	1
#   (9123, 14155)	1
#   (9123, 15469)	1
#   (9123, 16746)	1
#   (9123, 17114)	1
#   (9124, 151)	1
#   (9124, 160)	1
#   (9124, 296)	1
#   (9124, 3081)	1
#   (9124, 3139)	1
#   (9124, 3266)	1
#   (9124, 5645)	1
#   (9124, 6717)	1
#   (9124, 7312)	1
#   (9124, 8051)	1
#   (9124, 11074)	1
#   (9124, 11646)	1
#   (9124, 12012)	1
#   (9124, 12707)	1
#   (9124, 14708)	1
#   (9124, 16002)	1
#   (9124, 17083)	1
#   (9124, 17221)	1

# %%
features.PlotStripped
# Out:
# 0       cowboy doll profound threaten jealous new spac...
# 1       two kid find play magic board game, releas man...
# 2       john max resolv save belov bait shop turn ital...
# 3       base terri mcmillan novel, film follow four di...
# 4       georg bank must deal pregnanc daughter, also u...
# 5       group profession bank robber start feel heat p...
# 6       ugli duckl undergon remark change, still harbo...
# 7       tom huck wit injun joe kill doc robinson one n...
# 8       former fireman take group terrorist hold vice ...
# 9       jame bond team lone survivor destroy russian r...
# 10      comedy-drama widow u.s. presid lobbyist fall l...
# 11      mel brook parodi classic vampir stori famous f...
# 12      outcast half-wolf risk life prevent dead epide...
# 13      biograph stori former u.s. presid richard milh...
# 14      femal pirat companion race rival find hidden i...
# 15      greed, deception, money, power, murder occur t...
# 16      rich mr. dashwood dies, leav second wife three...
# 17      four interlock tale take place fade hotel new ...
# 18      ace ventura, pet detective, return spiritu que...
# 19      veng new york transit cop decid steal trainloa...
# 20      mobster travel hollywood collect debt discov m...
# 21      agoraphob psychologist femal detect must work ...
# 22      profession hit-man robert rath want fulfil con...
# 23      chart genius home school shun last relat die s...
# 24      ben sanderson, hollywood screenwrit lost every...
# 25      moorish general othello manipul think new wife...
# 26      four 12-year-old girl grow togeth event small-...
# 27      eight year earlier, ann elliot, daughter finan...
# 28      scientist surrealist societi kidnap children s...
# 29      provinci boy relat shanghai crime famili recru...
#                               ...
# 9095    face shredder, join forc mad scientist baxter ...
# 9096    becom clear solo album failure, former boy ban...
# 9097    lorrain ed warren travel north london help sin...
# 9098              american astronaut prepar mission mars.
# 9099    follow ghost invas manhattan, paranorm enthusi...
# 9100    reconnect awkward pal high school facebook, mi...
# 9101    cia danger former oper drawn hide uncov explos...
# 9102    maid room psycholog thriller explor complex re...
# 9103    tarzan, acclim life london, call back former h...
# 9104    former polic sergeant barn becom head secur se...
# 9105    two hard-parti brother place onlin ad find per...
# 9106    follow life valvano. includ reflect player man...
# 9107    desper rid toddler, dissatisfi bever hill hous...
# 9108    mother bird tri teach littl one find food hers...
# 9109    high school senior find immers onlin game trut...
# 9110    portrait christian gerhartsreiter, pose rockef...
# 9111    comput generat screenplay short scienc fiction...
# 9112    stori behind literari persona jt leroy, fictio...
# 9113    divorc father ex-con older brother resort desp...
# 9114    king regis, overse land lucis, command armi so...
# 9115    night turn dead three girl break seem empti ma...
# 9116    fin, famili cosmos bliss sharknado-fre five ye...
# 9117    man must cope loss wife obsolesc job find rede...
# 9118    young boy disappears, mother, polic chief, fri...
# 9119     1959, decor naval offic accus murder wife lover.
# 9120    2016 bc, kind farmer lead upris citi mohenjo d...
# 9121          japan plung chao upon appear giant monster.
# 9122    compil found footag featur music, interviews, ...
# 9123    chivo, singer work movi theater provid live en...
# 9124    intimate, person portrait women 1960s eye one ...
# Name: PlotStripped, Length: 9125, dtype: object
